# %% [markdown]
# ## Matemáticas Discretas

# %%
import itertools
list(itertools.combinations('ABCDE', 2))
# Out:
# [('A', 'B'),
#  ('A', 'C'),
#  ('A', 'D'),
#  ('A', 'E'),
#  ('B', 'C'),
#  ('B', 'D'),
#  ('B', 'E'),
#  ('C', 'D'),
#  ('C', 'E'),
#  ('D', 'E')]

# %%
list(itertools.combinations_with_replacement('ABCDE', 2))
# Out:
# [('A', 'A'),
#  ('A', 'B'),
#  ('A', 'C'),
#  ('A', 'D'),
#  ('A', 'E'),
#  ('B', 'B'),
#  ('B', 'C'),
#  ('B', 'D'),
#  ('B', 'E'),
#  ('C', 'C'),
#  ('C', 'D'),
#  ('C', 'E'),
#  ('D', 'D'),
#  ('D', 'E'),
#  ('E', 'E')]

# %%
import itertools
list(itertools.permutations('ABC', 2))
# Out:
# [('A', 'B'), ('A', 'C'), ('B', 'A'), ('B', 'C'), ('C', 'A'), ('C', 'B')]

# %%
import itertools
c = itertools.product(('A', 'B', 'C'), repeat=2)
#len(list(c))
print(list(c))
print(len(list(itertools.product(('A', 'B', 'C'), repeat=2))))
# Out:
# [('A', 'A'), ('A', 'B'), ('A', 'C'), ('B', 'A'), ('B', 'B'), ('B', 'C'), ('C', 'A'), ('C', 'B'), ('C', 'C')]
# 9

# %%
len(list(c))
# Out:
# 0

# %%
c = itertools.combinations(('A', 'B', 'C'), 2)
list(c)
# Out:
# [('A', 'B'), ('A', 'C'), ('B', 'C')]

# %%
c = itertools.permutations(('A', 'B', 'C'), 2)
list(c)
# Out:
# [('A', 'B'), ('A', 'C'), ('B', 'A'), ('B', 'C'), ('C', 'A'), ('C', 'B')]

# %% [markdown]
# ##Tarea 01: Octavos de Final de la Champion League 2019
#
# ¿Cual son los posibles combinaciones de partidos?
# ¿Cuantas combinaciones?
#
# Equipos finalistas:
# Porto, Roma, Manchester city, Schalke04, Bayer, Liverpool, Manchester United, PSG, Juventus, Atletico de Madrid, Barcelona, Lyon

# %%
len(list(itertools.combinations(( 'Porto', 'Roma', 'Manchester city', 'Schalke04', 'Bayer', 'Liverpool', 'Manchester United', 'PSG', 'Juventus', 'Atletico de Madrid', 'Barcelona', 'Lyon'),2)))
# Out:
# 66

# %%
print(len(list(itertools.combinations(( 'Porto', 'Roma', 'Manchester city', 'Schalke04', 'Bayer', 'Liverpool', 'Manchester United', 'PSG', 'Juventus', 'Atletico de Madrid', 'Barcelona', 'Lyon'),2))))
partidos = list(itertools.combinations(( 'Porto', 'Roma', 'Manchester city', 'Schalke04', 'Bayer', 'Liverpool', 'Manchester United', 'PSG', 'Juventus', 'Atletico de Madrid', 'Barcelona', 'Lyon'),2))
print(partidos)
# Out:
# 66
# ...

# %%
c = itertools.permutations(('Porto','roma','Manchester city','Schalke04','Bayer','Liverpool','Manchester United','PSG','juventus','Atletico de Madrid','Barcelona','Lyon'), 2)
 
list(c)
# Out:
# [('Porto', 'roma'),
#  ('Porto', 'Manchester city'),
#  ('Porto', 'Schalke04'),
#  ('Porto', 'Bayer'),
#  ('Porto', 'Liverpool'),
#  ('Porto', 'Manchester United'),
#  ('Porto', 'PSG'),
#  ('Porto', 'juventus'),
#  ('Porto', 'Atletico de Madrid'),
#  ('Porto', 'Barcelona'),
#  ('Porto', 'Lyon'),
#  ('roma', 'Porto'),
#  ('roma', 'Manchester city'),
#  ('roma', 'Schalke04'),
#  ('roma', 'Bayer'),
#  ('roma', 'Liverpool'),
#  ('roma', 'Manchester United'),
#  ('roma', 'PSG'),
#  ('roma', 'juventus'),
#  ('roma', 'Atletico de Madrid'),
#  ('roma', 'Barcelona'),
#  ('roma', 'Lyon'),
#  ('Manchester city', 'Porto'),
#  ('Manchester city', 'roma'),
#  ('Manchester city', 'Schalke04'),
#  ('Manchester city', 'Bayer'),
#  ('Manchester city', 'Liverpool'),
#  ('Manchester city', 'Manchester United'),
#  ('Manchester city', 'PSG'),
#  ('Manchester city', 'juventus'),
#  ('Manchester city', 'Atletico de Madrid'),
#  ('Manchester city', 'Barcelona'),
#  ('Manchester city', 'Lyon'),
# ...

# %%
import itertools
c = itertools.combinations (('Porto','Roma','Manchester City','Schalke04','Bayer','Liverpool','Manchester United','PSG','Juventus','Atletico de Madrid','Barcelona','Lyon'),2)
num=len(list(c))
print('El numero posible de encuentros es de: ',num)
c = itertools.combinations (('Porto','Roma','Manchester City','Schalke04','Bayer','Liverpool','Manchester United','PSG','Juventus','Atletico de Madrid','Barcelona','Lyon'),2)
list(c)
# Out:
# El numero posible de encuentros es de:  66
# [('Porto', 'Roma'),
#  ('Porto', 'Manchester City'),
#  ('Porto', 'Schalke04'),
#  ('Porto', 'Bayer'),
#  ('Porto', 'Liverpool'),
#  ('Porto', 'Manchester United'),
#  ('Porto', 'PSG'),
#  ('Porto', 'Juventus'),
#  ('Porto', 'Atletico de Madrid'),
#  ('Porto', 'Barcelona'),
#  ('Porto', 'Lyon'),
#  ('Roma', 'Manchester City'),
#  ('Roma', 'Schalke04'),
#  ('Roma', 'Bayer'),
#  ('Roma', 'Liverpool'),
#  ('Roma', 'Manchester United'),
#  ('Roma', 'PSG'),
#  ('Roma', 'Juventus'),
#  ('Roma', 'Atletico de Madrid'),
#  ('Roma', 'Barcelona'),
#  ('Roma', 'Lyon'),
#  ('Manchester City', 'Schalke04'),
#  ('Manchester City', 'Bayer'),
#  ('Manchester City', 'Liverpool'),
#  ('Manchester City', 'Manchester United'),
#  ('Manchester City', 'PSG'),
#  ('Manchester City', 'Juventus'),
#  ('Manchester City', 'Atletico de Madrid'),
#  ('Manchester City', 'Barcelona'),
#  ('Manchester City', 'Lyon'),
#  ('Schalke04', 'Bayer'),
# ...

# %%
from collections import defaultdict, namedtuple, Counter, deque
import csv
import random
from urllib.request import urlretrieve

# %%
pelicula_data = 'https://raw.githubusercontent.com/skielosky/2020-FISC-0746-Estructuras-Discretas-para-Computacion/master/data/movie_metadata.csv'
pelicula_csv = 'movies.csv'
urlretrieve(pelicula_data, pelicula_csv)
# Out:
# ('movies.csv', <http.client.HTTPMessage at 0x7fb159b5e6a0>)

# %%
pelicula = namedtuple('Peliculas', 'title year score')

# %%
def obtener_peliculas_por_director(data=pelicula_csv):
    """Extracts all movies from csv and stores them in a dictionary
       where keys are directors, and values is a list of movies (named tuples)"""
    directors = defaultdict(list)
    with open(data, encoding='utf-8') as f:
        for line in csv.DictReader(f):
            try:
                director = line['director_name']
                movie = line['movie_title'].replace('\xa0', '')
                year = int(line['title_year'])
                score = float(line['imdb_score'])
            except ValueError:
                continue

            m = pelicula(title=movie, year=year, score=score)
            directors[director].append(m)

    return directors

# %%
director = obtener_peliculas_por_director()

# %%
director
# Out:
# defaultdict(list,
#             {'James Cameron': [Peliculas(title='Avatar', year=2009, score=7.9),
#               Peliculas(title='Titanic', year=1997, score=7.7),
#               Peliculas(title='Terminator 2: Judgment Day', year=1991, score=8.5),
#               Peliculas(title='True Lies', year=1994, score=7.2),
#               Peliculas(title='The Abyss', year=1989, score=7.6),
#               Peliculas(title='Aliens', year=1986, score=8.4),
#               Peliculas(title='The Terminator', year=1984, score=8.1)],
#              'Gore Verbinski': [Peliculas(title="Pirates of the Caribbean: At World's End", year=2007, score=7.1),
#               Peliculas(title="Pirates of the Caribbean: Dead Man's Chest", year=2006, score=7.3),
#               Peliculas(title='The Lone Ranger', year=2013, score=6.5),
#               Peliculas(title='Rango', year=2011, score=7.2),
#               Peliculas(title='Pirates of the Caribbean: The Curse of the Black Pearl', year=2003, score=8.1),
# ...
